# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
import keras
from keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import helper
import copy
from importlib import reload

# %% [markdown]
# Load lại data

# %%
X_train, X_test, y_train, y_test = helper.load_data_RNN_case2()

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (5000, 30, 4)
# (5000, 4)

# %% [markdown]
# # Overfitting
# Sau khi thực hiện huấn luyện mô hình trên tập dữ liệu. Nhận thấy rằng đối với mô hình Feedforward Neural Network, mô hình có xu hướng rất tốt nên không cần phải thực hiện các giải pháp để giảm overfitting \
# Đối với mô hình Recurrent Neural Network, mô hình có xu hướng overfitting dựa trên độ đo (metrics) độ chính xác (accuracy ~ 0.6952) và có vài chỉ số f1-score cũng rất thấp \
# Chúng tôi chọn sử dụng mô hình Recurrent Neural Network với giả định trường hợp 2 để thực hiện giải pháp giảm overfitting.

# %% [markdown]
# ## Giải pháp 1 - Dropout và Early Stopping
# Giải pháp đầu tiên là sử dụng giải pháp Dropout để giảm độ phức tạp của mô hình học máy và Early Stopping\
# Giải pháp Early Stopping sẽ giúp ta giảm overfitting bằng cách dừng quá trình huấn luyện mô hình học máy khi độ chính xác trên tập dữ liệu kiểm thử không còn tăng nữa\
# Để thực hiện giải pháp Early Stopping, ta sẽ sử dụng EarlyStopping callback của thư viện Keras.

# %%
model_o = keras.models.Sequential([
    layers.LSTM(32, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    layers.Dense(4, activation='softmax'),
])
model_o.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history_o = model_o.fit(X_train, y_train, epochs=100, batch_size=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 3s 26ms/step - loss: 1.1919 - accuracy: 0.6010 - val_loss: 1.1359 - val_accuracy: 0.5220
# Epoch 2/100
# 40/40 [==============================] - 1s 16ms/step - loss: 0.9437 - accuracy: 0.6478 - val_loss: 1.0565 - val_accuracy: 0.5600
# Epoch 3/100
# 40/40 [==============================] - 1s 16ms/step - loss: 0.8619 - accuracy: 0.6890 - val_loss: 0.9278 - val_accuracy: 0.6640
# Epoch 4/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.8469 - accuracy: 0.7060 - val_loss: 1.0022 - val_accuracy: 0.6150
# Epoch 5/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.8167 - accuracy: 0.7080 - val_loss: 0.9195 - val_accuracy: 0.6640
# Epoch 6/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.7859 - accuracy: 0.7175 - val_loss: 0.9205 - val_accuracy: 0.6840
# Epoch 7/100
# 40/40 [==============================] - 1s 16ms/step - loss: 0.7765 - accuracy: 0.7207 - val_loss: 0.8955 - val_accuracy: 0.6790
# Epoch 8/100
# 40/40 [==============================] - 1s 17ms/step - loss: 0.7855 - accuracy: 0.7160 - val_loss: 0.9113 - val_accuracy: 0.6690
# Epoch 9/100
# 40/40 [==============================] - 1s 15ms/step - loss: 0.7710 - accuracy: 0.7230 - val_loss: 0.9012 - val_accuracy: 0.6690
# Epoch 10/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.7597 - accuracy: 0.7250 - val_loss: 0.8732 - val_accuracy: 0.6780
# Epoch 11/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7506 - accuracy: 0.7232 - val_loss: 0.8828 - val_accuracy: 0.6740
# Epoch 12/100
# 40/40 [==============================] - 1s 17ms/step - loss: 0.7485 - accuracy: 0.7230 - val_loss: 0.8908 - val_accuracy: 0.6670
# Epoch 13/100
# 40/40 [==============================] - 1s 15ms/step - loss: 0.7492 - accuracy: 0.7230 - val_loss: 0.9012 - val_accuracy: 0.6720
# Epoch 14/100
# 40/40 [==============================] - 1s 16ms/step - loss: 0.7423 - accuracy: 0.7245 - val_loss: 0.9113 - val_accuracy: 0.6670
# Epoch 15/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7410 - accuracy: 0.7303 - val_loss: 0.8719 - val_accuracy: 0.6670
# Epoch 16/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.7381 - accuracy: 0.7265 - val_loss: 0.8881 - val_accuracy: 0.6700
# Epoch 17/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.7356 - accuracy: 0.7265 - val_loss: 0.9068 - val_accuracy: 0.6860
# Epoch 18/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.7301 - accuracy: 0.7255 - val_loss: 0.8878 - val_accuracy: 0.6780
# Epoch 19/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.7324 - accuracy: 0.7295 - val_loss: 0.8836 - val_accuracy: 0.6840
# Epoch 20/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.7305 - accuracy: 0.7280 - val_loss: 0.8809 - val_accuracy: 0.6720
# Epoch 21/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.7258 - accuracy: 0.7305 - val_loss: 0.9083 - val_accuracy: 0.6860
# Epoch 22/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7221 - accuracy: 0.7283 - val_loss: 0.8858 - val_accuracy: 0.6720
# Epoch 23/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7178 - accuracy: 0.7275 - val_loss: 0.9046 - val_accuracy: 0.6670
# Epoch 24/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.7154 - accuracy: 0.7303 - val_loss: 0.8702 - val_accuracy: 0.6660
# Epoch 25/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.7152 - accuracy: 0.7285 - val_loss: 0.9231 - val_accuracy: 0.6640
# Epoch 26/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7099 - accuracy: 0.7315 - val_loss: 0.8824 - val_accuracy: 0.6770
# Epoch 27/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.7070 - accuracy: 0.7293 - val_loss: 0.9380 - val_accuracy: 0.6740
# Epoch 28/100
# 40/40 [==============================] - 1s 26ms/step - loss: 0.7061 - accuracy: 0.7285 - val_loss: 0.8813 - val_accuracy: 0.6730
# Epoch 29/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7035 - accuracy: 0.7275 - val_loss: 0.8800 - val_accuracy: 0.6680
# Epoch 30/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.7086 - accuracy: 0.7287 - val_loss: 0.9016 - val_accuracy: 0.6650
# Epoch 31/100
# 40/40 [==============================] - 1s 25ms/step - loss: 0.7018 - accuracy: 0.7340 - val_loss: 0.8800 - val_accuracy: 0.6600
# Epoch 32/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.7034 - accuracy: 0.7308 - val_loss: 0.9083 - val_accuracy: 0.6820
# Epoch 33/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.7163 - accuracy: 0.7247 - val_loss: 0.8927 - val_accuracy: 0.6760
# Epoch 34/100
# 40/40 [==============================] - 1s 25ms/step - loss: 0.7065 - accuracy: 0.7275 - val_loss: 0.9036 - val_accuracy: 0.6820
# Epoch 35/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6960 - accuracy: 0.7310 - val_loss: 0.8730 - val_accuracy: 0.6690
# Epoch 36/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6936 - accuracy: 0.7297 - val_loss: 0.8947 - val_accuracy: 0.6810
# Epoch 37/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6879 - accuracy: 0.7283 - val_loss: 0.9417 - val_accuracy: 0.6850
# Epoch 38/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.7040 - accuracy: 0.7283 - val_loss: 0.8876 - val_accuracy: 0.6590
# Epoch 39/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.6995 - accuracy: 0.7303 - val_loss: 0.8711 - val_accuracy: 0.6890
# Epoch 40/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6878 - accuracy: 0.7360 - val_loss: 0.8689 - val_accuracy: 0.6570
# Epoch 41/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6908 - accuracy: 0.7333 - val_loss: 0.8603 - val_accuracy: 0.6790
# Epoch 42/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.6856 - accuracy: 0.7322 - val_loss: 0.8734 - val_accuracy: 0.6840
# Epoch 43/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.6870 - accuracy: 0.7327 - val_loss: 0.8685 - val_accuracy: 0.6770
# Epoch 44/100
# 40/40 [==============================] - 1s 17ms/step - loss: 0.6873 - accuracy: 0.7337 - val_loss: 0.8502 - val_accuracy: 0.6570
# Epoch 45/100
# 40/40 [==============================] - 1s 17ms/step - loss: 0.6838 - accuracy: 0.7337 - val_loss: 0.8663 - val_accuracy: 0.6660
# Epoch 46/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6829 - accuracy: 0.7358 - val_loss: 0.8639 - val_accuracy: 0.6900
# Epoch 47/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6878 - accuracy: 0.7330 - val_loss: 0.8869 - val_accuracy: 0.6940
# Epoch 48/100
# 40/40 [==============================] - 1s 31ms/step - loss: 0.6783 - accuracy: 0.7352 - val_loss: 0.8628 - val_accuracy: 0.6700
# Epoch 49/100
# 40/40 [==============================] - 1s 17ms/step - loss: 0.6877 - accuracy: 0.7372 - val_loss: 0.8794 - val_accuracy: 0.6810
# Epoch 50/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6823 - accuracy: 0.7335 - val_loss: 0.8786 - val_accuracy: 0.6620
# Epoch 51/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.6789 - accuracy: 0.7370 - val_loss: 0.8552 - val_accuracy: 0.6900
# Epoch 52/100
# 40/40 [==============================] - 1s 30ms/step - loss: 0.6723 - accuracy: 0.7385 - val_loss: 0.8626 - val_accuracy: 0.6820
# Epoch 53/100
# 40/40 [==============================] - 1s 24ms/step - loss: 0.6726 - accuracy: 0.7325 - val_loss: 0.8707 - val_accuracy: 0.6820
# Epoch 54/100
# 40/40 [==============================] - 1s 25ms/step - loss: 0.6722 - accuracy: 0.7377 - val_loss: 0.8554 - val_accuracy: 0.6830
# Epoch 55/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6706 - accuracy: 0.7335 - val_loss: 0.9041 - val_accuracy: 0.6800
# Epoch 56/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6722 - accuracy: 0.7358 - val_loss: 0.8520 - val_accuracy: 0.6700
# Epoch 57/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6648 - accuracy: 0.7400 - val_loss: 0.8866 - val_accuracy: 0.6880
# Epoch 58/100
# 40/40 [==============================] - 1s 24ms/step - loss: 0.6667 - accuracy: 0.7377 - val_loss: 0.8564 - val_accuracy: 0.6740
# Epoch 59/100
# 40/40 [==============================] - 1s 23ms/step - loss: 0.6655 - accuracy: 0.7390 - val_loss: 0.8708 - val_accuracy: 0.6550
# Epoch 60/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6635 - accuracy: 0.7370 - val_loss: 0.8677 - val_accuracy: 0.6740
# Epoch 61/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6643 - accuracy: 0.7377 - val_loss: 0.8679 - val_accuracy: 0.6800
# Epoch 62/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6587 - accuracy: 0.7375 - val_loss: 0.8535 - val_accuracy: 0.6830
# Epoch 63/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6630 - accuracy: 0.7393 - val_loss: 0.9061 - val_accuracy: 0.6890
# Epoch 64/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6591 - accuracy: 0.7383 - val_loss: 0.8658 - val_accuracy: 0.6670
# Epoch 65/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6565 - accuracy: 0.7383 - val_loss: 0.8625 - val_accuracy: 0.6790
# Epoch 66/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6564 - accuracy: 0.7405 - val_loss: 0.9109 - val_accuracy: 0.6870
# Epoch 67/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6567 - accuracy: 0.7385 - val_loss: 0.8767 - val_accuracy: 0.6840
# Epoch 68/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6556 - accuracy: 0.7425 - val_loss: 0.8789 - val_accuracy: 0.6660
# Epoch 69/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6507 - accuracy: 0.7448 - val_loss: 0.8766 - val_accuracy: 0.6820
# Epoch 70/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6510 - accuracy: 0.7400 - val_loss: 0.8684 - val_accuracy: 0.6910
# Epoch 71/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6505 - accuracy: 0.7445 - val_loss: 0.8791 - val_accuracy: 0.7000
# Epoch 72/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6539 - accuracy: 0.7423 - val_loss: 0.8695 - val_accuracy: 0.6760
# Epoch 73/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6533 - accuracy: 0.7377 - val_loss: 0.8895 - val_accuracy: 0.6800
# Epoch 74/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6482 - accuracy: 0.7433 - val_loss: 0.8680 - val_accuracy: 0.6820
# Epoch 75/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6458 - accuracy: 0.7405 - val_loss: 0.8600 - val_accuracy: 0.6940
# Epoch 76/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6473 - accuracy: 0.7383 - val_loss: 0.8522 - val_accuracy: 0.6730
# Epoch 77/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6431 - accuracy: 0.7410 - val_loss: 0.8725 - val_accuracy: 0.6800
# Epoch 78/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6421 - accuracy: 0.7437 - val_loss: 0.9218 - val_accuracy: 0.6620
# Epoch 79/100
# 40/40 [==============================] - 1s 25ms/step - loss: 0.6455 - accuracy: 0.7415 - val_loss: 0.8482 - val_accuracy: 0.6610
# Epoch 80/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6371 - accuracy: 0.7473 - val_loss: 0.8829 - val_accuracy: 0.6670
# Epoch 81/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6408 - accuracy: 0.7462 - val_loss: 0.8597 - val_accuracy: 0.6630
# Epoch 82/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6361 - accuracy: 0.7450 - val_loss: 0.8755 - val_accuracy: 0.6660
# Epoch 83/100
# 40/40 [==============================] - 1s 23ms/step - loss: 0.6367 - accuracy: 0.7483 - val_loss: 0.8585 - val_accuracy: 0.6730
# Epoch 84/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6384 - accuracy: 0.7448 - val_loss: 0.8634 - val_accuracy: 0.6570
# Epoch 85/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6385 - accuracy: 0.7430 - val_loss: 0.9037 - val_accuracy: 0.6910
# Epoch 86/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6325 - accuracy: 0.7505 - val_loss: 0.8880 - val_accuracy: 0.6810
# Epoch 87/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6400 - accuracy: 0.7450 - val_loss: 0.8449 - val_accuracy: 0.6750
# Epoch 88/100
# 40/40 [==============================] - 1s 23ms/step - loss: 0.6353 - accuracy: 0.7465 - val_loss: 0.8568 - val_accuracy: 0.6750
# Epoch 89/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6372 - accuracy: 0.7462 - val_loss: 0.8510 - val_accuracy: 0.6790
# Epoch 90/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6294 - accuracy: 0.7483 - val_loss: 0.8858 - val_accuracy: 0.6720
# Epoch 91/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6299 - accuracy: 0.7452 - val_loss: 0.8656 - val_accuracy: 0.6720
# Epoch 92/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.6269 - accuracy: 0.7470 - val_loss: 0.8655 - val_accuracy: 0.6710
# Epoch 93/100
# 40/40 [==============================] - 1s 24ms/step - loss: 0.6292 - accuracy: 0.7485 - val_loss: 0.8630 - val_accuracy: 0.6790
# Epoch 94/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6258 - accuracy: 0.7455 - val_loss: 0.8578 - val_accuracy: 0.6710
# Epoch 95/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.6280 - accuracy: 0.7495 - val_loss: 0.8601 - val_accuracy: 0.6720
# Epoch 96/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6341 - accuracy: 0.7480 - val_loss: 0.8576 - val_accuracy: 0.6750
# Epoch 97/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6222 - accuracy: 0.7502 - val_loss: 0.8771 - val_accuracy: 0.6710
# Epoch 98/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6199 - accuracy: 0.7492 - val_loss: 0.8605 - val_accuracy: 0.6730
# Epoch 99/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.6240 - accuracy: 0.7473 - val_loss: 0.8887 - val_accuracy: 0.6700
# Epoch 100/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.6196 - accuracy: 0.7508 - val_loss: 0.8860 - val_accuracy: 0.6800

# %%
helper.plot_Loss_Val(history_o)

# %%
from keras.callbacks import EarlyStopping

# %%
model_drop = keras.models.Sequential([
    layers.LSTM(32, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    layers.Dropout(0.3),
    layers.Dense(4, activation='softmax'),
])

early_stopping = EarlyStopping(monitor='val_loss', patience=9, restore_best_weights=True)
model_drop.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history_drop = model_drop.fit(X_train, y_train, epochs=100, batch_size=100, callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 3s 26ms/step - loss: 1.2535 - accuracy: 0.5422 - val_loss: 1.2193 - val_accuracy: 0.5220
# Epoch 2/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.9944 - accuracy: 0.6425 - val_loss: 1.1132 - val_accuracy: 0.5220
# Epoch 3/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.9574 - accuracy: 0.6470 - val_loss: 1.0681 - val_accuracy: 0.5220
# Epoch 4/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.9016 - accuracy: 0.6687 - val_loss: 0.9999 - val_accuracy: 0.6180
# Epoch 5/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.8795 - accuracy: 0.6820 - val_loss: 0.9963 - val_accuracy: 0.6370
# Epoch 6/100
# 40/40 [==============================] - 1s 17ms/step - loss: 0.8524 - accuracy: 0.6935 - val_loss: 0.9481 - val_accuracy: 0.6460
# Epoch 7/100
# 40/40 [==============================] - 1s 17ms/step - loss: 0.8352 - accuracy: 0.7007 - val_loss: 0.9320 - val_accuracy: 0.6560
# Epoch 8/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.8231 - accuracy: 0.7067 - val_loss: 0.9243 - val_accuracy: 0.6500
# Epoch 9/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.8245 - accuracy: 0.7070 - val_loss: 0.9212 - val_accuracy: 0.6610
# Epoch 10/100
# 40/40 [==============================] - 1s 17ms/step - loss: 0.8128 - accuracy: 0.7070 - val_loss: 0.9289 - val_accuracy: 0.6500
# Epoch 11/100
# 40/40 [==============================] - 1s 17ms/step - loss: 0.8075 - accuracy: 0.7115 - val_loss: 0.9020 - val_accuracy: 0.6680
# Epoch 12/100
# 40/40 [==============================] - 1s 16ms/step - loss: 0.7993 - accuracy: 0.7110 - val_loss: 0.9199 - val_accuracy: 0.6700
# Epoch 13/100
# 40/40 [==============================] - 1s 17ms/step - loss: 0.7978 - accuracy: 0.7147 - val_loss: 0.8962 - val_accuracy: 0.6720
# Epoch 14/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7893 - accuracy: 0.7130 - val_loss: 0.9063 - val_accuracy: 0.6750
# Epoch 15/100
# 40/40 [==============================] - 1s 19ms/step - loss: 0.7802 - accuracy: 0.7120 - val_loss: 0.8876 - val_accuracy: 0.6730
# Epoch 16/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.7820 - accuracy: 0.7128 - val_loss: 0.8973 - val_accuracy: 0.6770
# Epoch 17/100
# 40/40 [==============================] - 1s 18ms/step - loss: 0.7691 - accuracy: 0.7200 - val_loss: 0.8904 - val_accuracy: 0.6750
# Epoch 18/100
# 40/40 [==============================] - 1s 16ms/step - loss: 0.7638 - accuracy: 0.7160 - val_loss: 0.8949 - val_accuracy: 0.6700
# Epoch 19/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.7602 - accuracy: 0.7175 - val_loss: 0.8978 - val_accuracy: 0.6740
# Epoch 20/100
# 40/40 [==============================] - 1s 25ms/step - loss: 0.7571 - accuracy: 0.7275 - val_loss: 0.8975 - val_accuracy: 0.6770
# Epoch 21/100
# 40/40 [==============================] - 1s 23ms/step - loss: 0.7626 - accuracy: 0.7182 - val_loss: 0.8937 - val_accuracy: 0.6800
# Epoch 22/100
# 40/40 [==============================] - 1s 23ms/step - loss: 0.7573 - accuracy: 0.7122 - val_loss: 0.9064 - val_accuracy: 0.6560
# Epoch 23/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.7534 - accuracy: 0.7210 - val_loss: 0.8864 - val_accuracy: 0.6780
# Epoch 24/100
# 40/40 [==============================] - 1s 24ms/step - loss: 0.7488 - accuracy: 0.7190 - val_loss: 0.8856 - val_accuracy: 0.6780
# Epoch 25/100
# 40/40 [==============================] - 1s 26ms/step - loss: 0.7380 - accuracy: 0.7235 - val_loss: 0.8911 - val_accuracy: 0.6790
# Epoch 26/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.7375 - accuracy: 0.7207 - val_loss: 0.8816 - val_accuracy: 0.6800
# Epoch 27/100
# 40/40 [==============================] - 1s 23ms/step - loss: 0.7402 - accuracy: 0.7230 - val_loss: 0.8927 - val_accuracy: 0.6850
# Epoch 28/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.7406 - accuracy: 0.7228 - val_loss: 0.9261 - val_accuracy: 0.6660
# Epoch 29/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.7340 - accuracy: 0.7243 - val_loss: 0.8896 - val_accuracy: 0.6810
# Epoch 30/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.7279 - accuracy: 0.7272 - val_loss: 0.8782 - val_accuracy: 0.6770
# Epoch 31/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7361 - accuracy: 0.7220 - val_loss: 0.8967 - val_accuracy: 0.6900
# Epoch 32/100
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7364 - accuracy: 0.7222 - val_loss: 0.8719 - val_accuracy: 0.6780
# Epoch 33/100
# 40/40 [==============================] - 1s 24ms/step - loss: 0.7216 - accuracy: 0.7272 - val_loss: 0.9155 - val_accuracy: 0.6780
# Epoch 34/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.7305 - accuracy: 0.7215 - val_loss: 0.8885 - val_accuracy: 0.6880
# Epoch 35/100
# 40/40 [==============================] - 1s 30ms/step - loss: 0.7314 - accuracy: 0.7237 - val_loss: 0.8943 - val_accuracy: 0.6840
# Epoch 36/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.7205 - accuracy: 0.7235 - val_loss: 0.8867 - val_accuracy: 0.6780
# Epoch 37/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.7230 - accuracy: 0.7325 - val_loss: 0.8844 - val_accuracy: 0.6880
# Epoch 38/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.7213 - accuracy: 0.7280 - val_loss: 0.9077 - val_accuracy: 0.6840
# Epoch 39/100
# 40/40 [==============================] - 1s 22ms/step - loss: 0.7175 - accuracy: 0.7258 - val_loss: 0.8803 - val_accuracy: 0.6750
# Epoch 40/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.7217 - accuracy: 0.7293 - val_loss: 0.8872 - val_accuracy: 0.6790
# Epoch 41/100
# 40/40 [==============================] - 1s 21ms/step - loss: 0.7107 - accuracy: 0.7270 - val_loss: 0.8886 - val_accuracy: 0.6910

# %%
helper.plot_Loss_Val(history_drop)

# %% [markdown]
# Sau khi thực hiện giải pháp Dropout (để giảm độ phức tạp của mô hình) và Early Stopping, ta thấy rằng khoảng cách validation loss gần với training loss và có xu hướng đã giảm. \
# Tuy nhiên do giá trị validation loss RNN model này ngay từ đầu có xu hướng giảm nên cũng không thể chắc chắn rằng model đã trở nên tốt hơn

# %% [markdown]
# ### Thử dự đoán model sau khi đã thực hiện giải pháp

# %%
print(classification_report(y_test.argmax(axis=1), model_drop.predict(X_test).argmax(axis=1)))
# Out:
# 29/29 [==============================] - 1s 10ms/step
#               precision    recall  f1-score   support
#
#            0       0.62      0.25      0.35       151
#            1       0.67      0.92      0.78       492
#            2       0.00      0.00      0.00        62
#            3       0.83      0.71      0.76       217
#
#     accuracy                           0.70       922
#    macro avg       0.53      0.47      0.47       922
# weighted avg       0.65      0.70      0.65       922
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Kết luận
# Sau khi dự đoán ta thấy chỉ số f1-score của class được encode 2 là 0 điều này chứng tỏ model sau khi sử dụng giải pháp 1 vẫn không có tiến triển

# %% [markdown]
# ## Giải pháp 2 - L2 regularization

# %%
from keras.regularizers import l2

# %%
model_l2 = keras.models.Sequential([
    layers.LSTM(32, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), kernel_regularizer=l2(0.01)),
    layers.Dense(4, activation='softmax'),
])
model_l2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history_l2 = model_l2.fit(X_train, y_train, epochs=20, validation_split=0.2, batch_size=100)
# Out:
# Epoch 1/20
# 40/40 [==============================] - 3s 23ms/step - loss: 1.2796 - accuracy: 0.5518 - val_loss: 1.1886 - val_accuracy: 0.5340
# Epoch 2/20
# 40/40 [==============================] - 1s 17ms/step - loss: 0.9941 - accuracy: 0.6513 - val_loss: 1.1136 - val_accuracy: 0.5820
# Epoch 3/20
# 40/40 [==============================] - 1s 18ms/step - loss: 0.9177 - accuracy: 0.6820 - val_loss: 1.0890 - val_accuracy: 0.6400
# Epoch 4/20
# 40/40 [==============================] - 1s 18ms/step - loss: 0.8775 - accuracy: 0.6955 - val_loss: 0.9632 - val_accuracy: 0.6610
# Epoch 5/20
# 40/40 [==============================] - 1s 18ms/step - loss: 0.8373 - accuracy: 0.7128 - val_loss: 0.9278 - val_accuracy: 0.6610
# Epoch 6/20
# 40/40 [==============================] - 1s 17ms/step - loss: 0.8183 - accuracy: 0.7197 - val_loss: 0.9225 - val_accuracy: 0.6730
# Epoch 7/20
# 40/40 [==============================] - 1s 16ms/step - loss: 0.8278 - accuracy: 0.7125 - val_loss: 0.9219 - val_accuracy: 0.6650
# Epoch 8/20
# 40/40 [==============================] - 1s 20ms/step - loss: 0.8045 - accuracy: 0.7193 - val_loss: 0.9465 - val_accuracy: 0.6840
# Epoch 9/20
# 40/40 [==============================] - 1s 18ms/step - loss: 0.8060 - accuracy: 0.7168 - val_loss: 0.9178 - val_accuracy: 0.6770
# Epoch 10/20
# 40/40 [==============================] - 1s 16ms/step - loss: 0.7946 - accuracy: 0.7195 - val_loss: 0.9098 - val_accuracy: 0.6780
# Epoch 11/20
# 40/40 [==============================] - 1s 16ms/step - loss: 0.7856 - accuracy: 0.7293 - val_loss: 0.9344 - val_accuracy: 0.6410
# Epoch 12/20
# 40/40 [==============================] - 1s 17ms/step - loss: 0.7855 - accuracy: 0.7225 - val_loss: 0.9276 - val_accuracy: 0.6550
# Epoch 13/20
# 40/40 [==============================] - 1s 24ms/step - loss: 0.7832 - accuracy: 0.7195 - val_loss: 0.9033 - val_accuracy: 0.6670
# Epoch 14/20
# 40/40 [==============================] - 1s 21ms/step - loss: 0.7790 - accuracy: 0.7250 - val_loss: 0.9167 - val_accuracy: 0.6630
# Epoch 15/20
# 40/40 [==============================] - 1s 22ms/step - loss: 0.7767 - accuracy: 0.7182 - val_loss: 0.9201 - val_accuracy: 0.6640
# Epoch 16/20
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7804 - accuracy: 0.7232 - val_loss: 0.9150 - val_accuracy: 0.6740
# Epoch 17/20
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7703 - accuracy: 0.7270 - val_loss: 0.9060 - val_accuracy: 0.6660
# Epoch 18/20
# 40/40 [==============================] - 1s 20ms/step - loss: 0.7676 - accuracy: 0.7210 - val_loss: 0.8987 - val_accuracy: 0.6720
# Epoch 19/20
# 40/40 [==============================] - 1s 23ms/step - loss: 0.7629 - accuracy: 0.7230 - val_loss: 0.9383 - val_accuracy: 0.6820
# Epoch 20/20
# 40/40 [==============================] - 1s 21ms/step - loss: 0.7694 - accuracy: 0.7207 - val_loss: 0.8934 - val_accuracy: 0.6660

# %%
helper.plot_Loss_Val(history_l2)

# %% [markdown]
# Tương tự như giải pháp Dropout, ta thấy rằng khoảng cách validation loss gần với training loss và có xu hướng đã giảm. \
# Tuy nhiên do giá trị validation loss RNN model này ngay từ đầu có xu hướng giảm nên cũng không thể chắc chắn rằng model đã trở nên tốt hơn

# %% [markdown]
# ### Thử dự đoán sau khi sử dụng giải pháp

# %%
print(classification_report(y_test.argmax(axis=1), model_drop.predict(X_test).argmax(axis=1)))
# Out:
#  1/29 [>.............................] - ETA: 1s
# 29/29 [==============================] - 0s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.62      0.25      0.35       151
#            1       0.67      0.92      0.78       492
#            2       0.00      0.00      0.00        62
#            3       0.83      0.71      0.76       217
#
#     accuracy                           0.70       922
#    macro avg       0.53      0.47      0.47       922
# weighted avg       0.65      0.70      0.65       922
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Kết luận
# Tương tự như giải pháp 1, model sau khi sử dụng giải pháp này vẫn không tiến triển

# %% [markdown]
# # Cải thiện độ chính xác

# %% [markdown]
# ## Giải pháp 1 - LSTM đa chiều
# Giải pháp sử dụng LSTM đa chiều sẽ giúp ta cải thiện độ chính xác bằng cách sử dụng LSTM đa chiều (Bidirectional LSTM) thay vì sử dụng LSTM đơn chiều (LSTM). <br>
# Qua đó, lớp LSTM đa chiều (Bidirectional LSTM) sẽ giúp ta cải thiện độ chính xác bằng cách xem xét cả thông tin từ quá khứ và tương lai. <br>
# Để thực hiện giải pháp sử dụng LSTM đa chiều, ta sẽ sử dụng lớp Bidirectional của thư viện Keras. <br>

# %%
model_bid = keras.models.Sequential([
    layers.Input(shape=(X_train.shape[1], X_test.shape[2])),
    layers.Bidirectional(layers.LSTM(10, return_sequences=True)),
    layers.Bidirectional(layers.LSTM(10)),
    layers.Dense(4, activation='softmax')
])
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model_bid.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model_bid.fit(X_train, y_train, epochs=50, callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/50
# 125/125 [==============================] - 13s 39ms/step - loss: 1.0357 - accuracy: 0.6137 - val_loss: 1.1054 - val_accuracy: 0.5220
# Epoch 2/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.8541 - accuracy: 0.6942 - val_loss: 0.9408 - val_accuracy: 0.6730
# Epoch 3/50
# 125/125 [==============================] - 3s 26ms/step - loss: 0.7858 - accuracy: 0.7203 - val_loss: 0.8884 - val_accuracy: 0.6880
# Epoch 4/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.7546 - accuracy: 0.7247 - val_loss: 0.8721 - val_accuracy: 0.6820
# Epoch 5/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.7374 - accuracy: 0.7283 - val_loss: 0.8812 - val_accuracy: 0.6740
# Epoch 6/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.7268 - accuracy: 0.7297 - val_loss: 0.8757 - val_accuracy: 0.6870
# Epoch 7/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.7156 - accuracy: 0.7325 - val_loss: 0.8923 - val_accuracy: 0.6860
# Epoch 8/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.7107 - accuracy: 0.7358 - val_loss: 0.8609 - val_accuracy: 0.6870
# Epoch 9/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.7072 - accuracy: 0.7340 - val_loss: 0.8622 - val_accuracy: 0.6750
# Epoch 10/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.7010 - accuracy: 0.7310 - val_loss: 0.8669 - val_accuracy: 0.6620
# Epoch 11/50
# 125/125 [==============================] - 3s 26ms/step - loss: 0.6953 - accuracy: 0.7405 - val_loss: 0.8805 - val_accuracy: 0.6680
# Epoch 12/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.6942 - accuracy: 0.7387 - val_loss: 0.8645 - val_accuracy: 0.6760
# Epoch 13/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.6909 - accuracy: 0.7370 - val_loss: 0.8660 - val_accuracy: 0.6850

# %%
helper.plot_Loss_Val(history)

# %%
helper.plot_Accuracy(history)

# %% [markdown]
# Sau khi training ta thấy accuracy của model có sử dụng bidirection gia tăng lên mức ~ 0.72 khác model RNN - LSTM một chiều có accuracy chỉ ~ 0.67 \
# Tuy accuarcy tăng không nhiều, song chỉ số accuarcy tăng không đồng nghĩa với model ta đã cải thiện.

# %% [markdown]
# ### Thử dự đoán sau khi áp dụng giải pháp

# %%
print(classification_report(y_test.argmax(axis=1), model_bid.predict(X_test).argmax(axis=1)))
# Out:
# 29/29 [==============================] - 2s 9ms/step
#               precision    recall  f1-score   support
#
#            0       0.60      0.25      0.36       151
#            1       0.71      0.91      0.80       492
#            2       0.00      0.00      0.00        62
#            3       0.80      0.86      0.83       217
#
#     accuracy                           0.73       922
#    macro avg       0.53      0.50      0.50       922
# weighted avg       0.67      0.73      0.68       922
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Kết luận
# Bidirection LSTM model tuy có accuracy được cải thiện xong vẫn không phải là model tốt do f1-score của class encode 2 chỉ là 0
